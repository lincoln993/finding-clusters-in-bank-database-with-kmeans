# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
creditcard_df = pd.read_csv('/content/drive/MyDrive/Marketing/Marketing_data.csv')

# %%
creditcard_df.shape
# Out:
# (8950, 18)

# %%
creditcard_df.head()
# Out:
#   CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 0  C10001    40.900749  ...          0.000000      12
# 1  C10002  3202.467416  ...          0.222222      12
# 2  C10003  2495.148862  ...          0.000000      12
# 3  C10004  1666.670542  ...          0.000000      12
# 4  C10005   817.714335  ...          0.000000      12
#
# [5 rows x 18 columns]

# %%
creditcard_df.info
# Out:
# <bound method DataFrame.info of      CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 0     C10001    40.900749  ...          0.000000      12
# 1     C10002  3202.467416  ...          0.222222      12
# 2     C10003  2495.148862  ...          0.000000      12
# 3     C10004  1666.670542  ...          0.000000      12
# 4     C10005   817.714335  ...          0.000000      12
# ...      ...          ...  ...               ...     ...
# 8945  C19186    28.493517  ...          0.500000       6
# 8946  C19187    19.183215  ...          0.000000       6
# 8947  C19188    23.398673  ...          0.250000       6
# 8948  C19189    13.457564  ...          0.250000       6
# 8949  C19190   372.708075  ...          0.000000       6
#
# [8950 rows x 18 columns]>

# %%
creditcard_df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT       TENURE
# count   8950.000000        8950.000000  ...       8950.000000  8950.000000
# mean    1564.474828           0.877271  ...          0.153715    11.517318
# std     2081.531879           0.236904  ...          0.292499     1.338331
# min        0.000000           0.000000  ...          0.000000     6.000000
# 25%      128.281915           0.888889  ...          0.000000    12.000000
# 50%      873.385231           1.000000  ...          0.000000    12.000000
# 75%     2054.140036           1.000000  ...          0.142857    12.000000
# max    19043.138560           1.000000  ...          1.000000    12.000000
#
# [8 rows x 17 columns]

# %%
creditcard_df[creditcard_df['CASH_ADVANCE'] == creditcard_df['CASH_ADVANCE'].max()]
# Out:
#      CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 2159  C12226  10905.05381  ...               0.0      12
#
# [1 rows x 18 columns]

# %%
creditcard_df[creditcard_df['ONEOFF_PURCHASES'] == creditcard_df['ONEOFF_PURCHASES'].max()]
# Out:
#     CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 550  C10574  11547.52001  ...              0.25      12
#
# [1 rows x 18 columns]

# %%
sns.heatmap(creditcard_df.isnull());

# %%
creditcard_df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
creditcard_df.loc[(creditcard_df['MINIMUM_PAYMENTS'].isnull() == True), 'MINIMUM_PAYMENTS'] = creditcard_df['MINIMUM_PAYMENTS'].mean()

# %%
creditcard_df['MINIMUM_PAYMENTS'].mean()
# Out:
# 864.206542305076

# %%
creditcard_df.loc[(creditcard_df['CREDIT_LIMIT'].isnull() == True), 'CREDIT_LIMIT'] = creditcard_df['CREDIT_LIMIT'].mean()

# %%
creditcard_df['CREDIT_LIMIT'].mean()
# Out:
# 4494.449450364622

# %%
sns.heatmap(creditcard_df.isnull());

# %%
creditcard_df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
creditcard_df.duplicated().sum()
# Out:
# 0

# %%
creditcard_df.drop('CUST_ID', axis=1, inplace=True)

# %%
creditcard_df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT  TENURE
# 0    40.900749           0.818182  ...          0.000000      12
# 1  3202.467416           0.909091  ...          0.222222      12
# 2  2495.148862           1.000000  ...          0.000000      12
# 3  1666.670542           0.636364  ...          0.000000      12
# 4   817.714335           1.000000  ...          0.000000      12
#
# [5 rows x 17 columns]

# %%
creditcard_df.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
plt.figure(figsize=(10,50))
for i in range(len(creditcard_df.columns)):
  plt.subplot(17, 1, i + 1);
  sns.histplot(creditcard_df[creditcard_df.columns[i]], kde = True);
  plt.title(creditcard_df.columns[i]);
plt.tight_layout();

# %%
correlations = creditcard_df.corr()

# %%
f, ax = plt.subplots(figsize=(20,20))
sns.heatmap(correlations, annot=True)

# %%
correlations = creditcard_df.corr()['PAYMENTS'].sort_values()
correlations
# Out:
# BALANCE_FREQUENCY                   0.065008
# PURCHASES_INSTALLMENTS_FREQUENCY    0.085551
# PURCHASES_FREQUENCY                 0.103464
# TENURE                              0.106136
# PRC_FULL_PAYMENT                    0.112138
# MINIMUM_PAYMENTS                    0.125046
# CASH_ADVANCE_FREQUENCY              0.183192
# ONEOFF_PURCHASES_FREQUENCY          0.243537
# CASH_ADVANCE_TRX                    0.255278
# BALANCE                             0.322802
# PURCHASES_TRX                       0.370832
# INSTALLMENTS_PURCHASES              0.384084
# CREDIT_LIMIT                        0.421852
# CASH_ADVANCE                        0.453238
# ONEOFF_PURCHASES                    0.567292
# PURCHASES                           0.603264
# PAYMENTS                            1.000000
# Name: PAYMENTS, dtype: float64

# %%
min(creditcard_df['BALANCE']), max(creditcard_df['BALANCE'])
# Out:
# (0.0, 19043.13856)

# %%
scaler = StandardScaler()
creditcard_df_scaled = scaler.fit_transform(creditcard_df)

# %%
min(creditcard_df_scaled[0]), max(creditcard_df_scaled[0])
# Out:
# (-0.9604333444542572, 0.36067954425377496)

# %%
wcss_1 = []
range_values = range(1, 20)
for i in range_values:
  kmeans = KMeans(n_clusters=i)
  kmeans.fit(creditcard_df_scaled)
  wcss_1.append(kmeans.inertia_)

# %%
print(wcss_1)
# Out:
# [152149.99999999983, 127784.8744914511, 111986.69806610125, 99073.93826774803, 91501.9691604366, 84852.02054259737, 79532.4097382905, 74510.18965579929, 69857.95472907285, 66610.63204447563, 63632.94710602802, 61372.765241569796, 59163.03132850802, 57496.10946589171, 55919.08329080316, 54676.688433732386, 53258.99289824632, 51908.75102535712, 50675.93756598563]

# %%
plt.plot(wcss_1, 'bx-')
plt.xlabel('Clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
kmeans = KMeans(n_clusters=8)
kmeans.fit(creditcard_df_scaled)
labels = kmeans.labels_

# %%
labels
# Out:
# array([0, 4, 7, ..., 3, 3, 3], dtype=int32)

# %%
np.unique(labels, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7], dtype=int32),
#  array([2755, 2009,   25,  623,  877,  358, 1183, 1120]))

# %%
clusters_centers = pd.DataFrame(data=kmeans.cluster_centers_, columns=[creditcard_df.columns])
clusters_centers
# Out:
#     BALANCE BALANCE_FREQUENCY  ... PRC_FULL_PAYMENT    TENURE
# 0  0.010094          0.404363  ...        -0.455592  0.274157
# 1 -0.361841          0.332550  ...         0.316529  0.255791
# 2  1.819469          0.301643  ...         1.152351  0.300900
# 3 -0.336228         -0.347383  ...         0.014243 -3.202809
# 4  1.680514          0.392139  ...        -0.390511  0.069801
# 5  1.044635          0.467595  ...         0.246267  0.337720
# 6 -0.701044         -2.140609  ...         0.281238  0.198977
# 7 -0.137076          0.399815  ...         0.448517  0.268691
#
# [8 rows x 17 columns]

# %%
clusters_centers = scaler.inverse_transform(clusters_centers)
clusters_centers = pd.DataFrame(data = clusters_centers, columns=[creditcard_df.columns])
clusters_centers
# Out:
#        BALANCE BALANCE_FREQUENCY  ... PRC_FULL_PAYMENT     TENURE
# 0  1585.484650          0.973061  ...         0.020462  11.884211
# 1   811.333806          0.956049  ...         0.246294  11.859632
# 2  5351.546106          0.948727  ...         0.490758  11.920000
# 3   864.645308          0.794979  ...         0.157880   7.231140
# 4  5062.323464          0.970165  ...         0.039497  11.610731
# 5  3738.793623          0.988040  ...         0.225744  11.969274
# 6   105.310374          0.370180  ...         0.235972  11.783601
# 7  1279.162853          0.971983  ...         0.284898  11.876896
#
# [8 rows x 17 columns]

# %%
creditcard_df_cluster = pd.concat([creditcard_df, pd.DataFrame({'cluster': labels})], axis=1)
creditcard_df_cluster.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ...  PRC_FULL_PAYMENT  TENURE  cluster
# 0    40.900749           0.818182      95.40  ...          0.000000      12        0
# 1  3202.467416           0.909091       0.00  ...          0.222222      12        4
# 2  2495.148862           1.000000     773.17  ...          0.000000      12        7
# 3  1666.670542           0.636364    1499.00  ...          0.000000      12        0
# 4   817.714335           1.000000      16.00  ...          0.000000      12        0
#
# [5 rows x 18 columns]

# %%
for i in creditcard_df.columns:
  plt.figure(figsize=(35,5))
  for j in range(8):
    plt.subplot(1, 8, j + 1)
    cluster = creditcard_df_cluster[creditcard_df_cluster['cluster'] == j]
    cluster[i].hist(bins=20)
    plt.title('{}\n Cluster {}'.format(i, j))

# %%
credit_orded = creditcard_df_cluster.sort_values(by='cluster')
credit_orded.head()
# Out:
#           BALANCE  BALANCE_FREQUENCY  ...  TENURE  cluster
# 0       40.900749           0.818182  ...      12        0
# 4226    41.643083           1.000000  ...      12        0
# 4227   291.663664           1.000000  ...      12        0
# 4228  1437.977941           1.000000  ...      12        0
# 4230  2063.855487           1.000000  ...      12        0
#
# [5 rows x 18 columns]

# %%
credit_orded.tail()
# Out:
#          BALANCE  BALANCE_FREQUENCY  ...  TENURE  cluster
# 544   950.563525           0.909091  ...      11        7
# 1497  136.743106           1.000000  ...      12        7
# 4019  196.967268           1.000000  ...      12        7
# 3128   99.527723           0.818182  ...      12        7
# 6090  250.758639           1.000000  ...      12        7
#
# [5 rows x 18 columns]

# %%
credit_orded.to_csv('clusters.csv')

# %%
pca = PCA(n_components=2)
principal_comp = pca.fit_transform(creditcard_df_scaled)
principal_comp
# Out:
# array([[-1.68222091, -1.07644877],
#        [-1.13829861,  2.50649087],
#        [ 0.96968514, -0.38351532],
#        ...,
#        [-0.92620281, -1.81079009],
#        [-2.3365506 , -0.65797435],
#        [-0.55642059, -0.40047158]])

# %%
pca_df = pd.DataFrame(data = principal_comp, columns=['pca1', 'pca2'])
pca_df.head()
# Out:
#        pca1      pca2
# 0 -1.682221 -1.076449
# 1 -1.138299  2.506491
# 2  0.969685 -0.383515
# 3 -0.873630  0.043171
# 4 -1.599434 -0.688581

# %%
pca_df = pd.concat([pca_df, pd.DataFrame({'cluster': labels})], axis=1)
pca_df.head()
# Out:
#        pca1      pca2  cluster
# 0 -1.682221 -1.076449        0
# 1 -1.138299  2.506491        4
# 2  0.969685 -0.383515        7
# 3 -0.873630  0.043171        0
# 4 -1.599434 -0.688581        0

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='pca1', y='pca2', hue='cluster', data=pca_df, palette=['red', 'green', 'blue', 'pink', 'yellow', 'gray', 'purple', 'black'])
